# %%
1].if the data (images/text) is in zip files make the separate column

2] make 3 column train,test,validation

3]copy data n paste in 3 columns

4] make a different category for all 3 column ex.like :- happy , sad , blackwhite

5]follow the step below here

6]copy the url / link paste and use 'r' before link r used for specific value /parameter

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import tensorflow as tf
import cv2
import os
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 32

# %%
img = image.load_img(r"C:\Users\ADIL SHAIKH\Downloads\train\WhatsApp Image 2024-06-25 at 10.08.28 PM (1).jpeg")

# %%
plt.imshow(img)

# %%
cv2.imread(r"C:\Users\ADIL SHAIKH\Downloads\train\WhatsApp Image 2024-06-25 at 10.08.28 PM (1).jpeg")
# Out:
# array([[[166, 166, 150],
#         [166, 166, 150],
#         [165, 165, 149],
#         ...,
#         [163, 162, 141],
#         [152, 154, 134],
#         [147, 151, 132]],
#
#        [[166, 166, 150],
#         [165, 165, 149],
#         [165, 165, 149],
#         ...,
#         [162, 161, 141],
#         [148, 150, 131],
#         [142, 146, 127]],
#
#        [[165, 165, 149],
#         [165, 165, 149],
#         [165, 165, 149],
#         ...,
#         [157, 157, 139],
#         [140, 143, 127],
#         [133, 139, 122]],
#
#        ...,
#
#        [[ 41,  20, 142],
#         [ 42,  21, 143],
#         [ 44,  25, 146],
#         ...,
#         [ 43,  32, 178],
#         [ 47,  38, 182],
#         [ 45,  39, 182]],
#
#        [[ 45,  22, 144],
#         [ 44,  23, 145],
#         [ 44,  25, 146],
#         ...,
#         [ 43,  32, 178],
#         [ 43,  34, 178],
#         [ 38,  32, 175]],
#
#        [[ 44,  21, 143],
#         [ 43,  22, 144],
#         [ 45,  24, 146],
# ...

# %%
cv2.imread(r"C:\Users\ADIL SHAIKH\Downloads\train\WhatsApp Image 2024-06-25 at 10.08.28 PM (1).jpeg").shape
# Out:
# (1280, 960, 3)

# %%
1280 - hight 
960 - width
3 - 3 metrix dimention (color)
